# %%
from google.colab import drive
drive.mount('/gdrive', force_remount=True)
# Out:
# Mounted at /gdrive

# %%
# !ls '/gdrive/My Drive/DS_contest'
# Out:
# '참고코드(태양광)'   data2.csv	   examSet.csv	  Figures	   tsa.csv
#  211118_chat.txt     datasix.csv   examTSA2.csv   Finaldata1.csv   파일설명.txt
#  211118_video.mp4    df1.csv	   examTSA3.csv   Modeling
#  data1.csv	     df2.csv	   examTSA4.csv   Preprocessing
#  data1_mid.csv	     df2_sg.csv    examTSA.csv	  trainSet.csv

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as plot
import datetime as dt
import math
df1 = pd.read_csv('/gdrive/My Drive/DS_contest/data1.csv')

# %% [markdown]
# ## **df1 Preprocessing**

# %% [markdown]
# Stimulation Fluid Preprocessing

# %%
for i in range(280):
  if df1['Stimulation Fluid'][i] == 'Oil':
    df1['Stimulation Fluid'][i] = 0
  elif df1['Stimulation Fluid'][i] == 'Oil: CWS-DynaGel':
    df1['Stimulation Fluid'][i] = 1
  elif df1['Stimulation Fluid'][i] == 'Oil: HAL-My-T-Oil':
    df1['Stimulation Fluid'][i] = 2
  elif df1['Stimulation Fluid'][i] == 'Oil: BJ-Super Rheo Gel':
    df1['Stimulation Fluid'][i] = 3
  elif df1['Stimulation Fluid'][i] == 'Water':
    df1['Stimulation Fluid'][i] = 4
  elif df1['Stimulation Fluid'][i] == 'Water: SLB-WaterFrac (WF)':
    df1['Stimulation Fluid'][i] = 5
  elif df1['Stimulation Fluid'][i] == 'Water: HAL-Hybor':
    df1['Stimulation Fluid'][i] = 6
  elif df1['Stimulation Fluid'][i] == 'Water: HAL-Water Frac G':
    df1['Stimulation Fluid'][i] = 7
  elif df1['Stimulation Fluid'][i] == 'Water: Sanjel-N2 FOAMjel':
    df1['Stimulation Fluid'][i] = 8
  elif df1['Stimulation Fluid'][i] == 'Water: TWS-Nitrified Foam (NF)':
    df1['Stimulation Fluid'][i] = 9
  elif df1['Stimulation Fluid'][i] == 'Water: SLB-WideFrac (YF)':
    df1['Stimulation Fluid'][i] = 10
  elif df1['Stimulation Fluid'][i] == 'Water: CSG-Optimum':
    df1['Stimulation Fluid'][i] = 11
  elif df1['Stimulation Fluid'][i] == 'Water: SLB-WideFrac (YF)/HiWAY':
    df1['Stimulation Fluid'][i] = 12
  elif df1['Stimulation Fluid'][i] == 'Slickwater':
    df1['Stimulation Fluid'][i] = 13
  elif df1['Stimulation Fluid'][i] == 'Slickwater: STEP-SW':
    df1['Stimulation Fluid'][i] = 14
  elif df1['Stimulation Fluid'][i] == 'STEP-SW':
    df1['Stimulation Fluid'][i] = 14
  elif df1['Stimulation Fluid'][i] == 'Slickwater: BJ-ThinFrac':
    df1['Stimulation Fluid'][i] = 15
  elif df1['Stimulation Fluid'][i] == 'Slickwater: CWS-600':
    df1['Stimulation Fluid'][i] = 16
  elif df1['Stimulation Fluid'][i] == 'Slickwater: TWS-EcoClean-GSW':
    df1['Stimulation Fluid'][i] = 17
  elif df1['Stimulation Fluid'][i] == 'Slickwater: CSG-Optimum SW':
    df1['Stimulation Fluid'][i] = 18
  elif df1['Stimulation Fluid'][i] == 'Slickwater & Water':
    df1['Stimulation Fluid'][i] = 19

# %% [markdown]
# Proppant Composition Preprocessing

# %%
for i in range(280):
  if df1['Proppant Composition'][i] == 'Ceramic/Sand':
    df1['Proppant Composition'][i] = 0
  elif df1['Proppant Composition'][i] == 'Sand':
    df1['Proppant Composition'][i] = 1

# %% [markdown]
# Proppant Name 1 Preprocessing

# %%
for i in range(280):
  if df1['Proppant Name 1'][i] == 'FTecISP':
    df1['Proppant Name 1'][i] = 0
  elif df1['Proppant Name 1'][i] == 'HydroProp':
    df1['Proppant Name 1'][i] = 1
  elif df1['Proppant Name 1'][i] == 'Sand':
    df1['Proppant Name 1'][i] = 2
  elif df1['Proppant Name 1'][i] == 'White':
    df1['Proppant Name 1'][i] = 3
  elif df1['Proppant Name 1'][i] == 'Imported':
    df1['Proppant Name 1'][i] = 4
  elif df1['Proppant Name 1'][i] == 'Badger':
    df1['Proppant Name 1'][i] = 5
  elif df1['Proppant Name 1'][i] == 'Domestic':
    df1['Proppant Name 1'][i] = 6
  elif df1['Proppant Name 1'][i] == 'Brown':
    df1['Proppant Name 1'][i] = 7
  elif df1['Proppant Name 1'][i] == 'EconoProp':
    df1['Proppant Name 1'][i] = 8
  elif df1['Proppant Name 1'][i] == 'Ceramic':
    df1['Proppant Name 1'][i] = 9
  elif df1['Proppant Name 1'][i] == 'FTec':
    df1['Proppant Name 1'][i] = 10
  elif df1['Proppant Name 1'][i] == 'Oxane Ceramic':
    df1['Proppant Name 1'][i] = 11
  elif df1['Proppant Name 1'][i] == 'Ottawa':
    df1['Proppant Name 1'][i] = 12

# %% [markdown]
# Proppant Size 1 Preprocessing

# %%
for i in range(280):
  for j in str(df1['Proppant Size 1'][i]):
    if j == '/':
      a1 = str(df1['Proppant Size 1'][i])[0:2]
      a2 = str(df1['Proppant Size 1'][i])[3:5]
      a1 = int(a1)
      a2 = int(a2)
      df2['Proppant Size 1'][i] = (a1 + a2) / 2
    else:
      continue
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# ##**df2 Preprocessing**

# %%
df2 = pd.read_csv('/gdrive/My Drive/DS_contest/df2.csv')

# %% [markdown]
# Stimulation Fluid Preprocessing

# %%
for i in range(8352):
  if df2['Stimulation Fluid'][i] == 'Oil':
    df2['Stimulation Fluid'][i] = 0
  elif df2['Stimulation Fluid'][i] == 'Oil: CWS-DynaGel':
    df2['Stimulation Fluid'][i] = 1
  elif df2['Stimulation Fluid'][i] == 'Oil: HAL-My-T-Oil':
    df2['Stimulation Fluid'][i] = 2
  elif df2['Stimulation Fluid'][i] == 'Oil: BJ-Super Rheo Gel':
    df2['Stimulation Fluid'][i] = 3
  elif df2['Stimulation Fluid'][i] == 'Water':
    df2['Stimulation Fluid'][i] = 4
  elif df2['Stimulation Fluid'][i] == 'Water: SLB-WaterFrac (WF)':
    df2['Stimulation Fluid'][i] = 5
  elif df2['Stimulation Fluid'][i] == 'Water: HAL-Hybor':
    df2['Stimulation Fluid'][i] = 6
  elif df2['Stimulation Fluid'][i] == 'Water: HAL-Water Frac G':
    df2['Stimulation Fluid'][i] = 7
  elif df2['Stimulation Fluid'][i] == 'Water: Sanjel-N2 FOAMjel':
    df2['Stimulation Fluid'][i] = 8
  elif df2['Stimulation Fluid'][i] == 'Water: TWS-Nitrified Foam (NF)':
    df2['Stimulation Fluid'][i] = 9
  elif df2['Stimulation Fluid'][i] == 'Water: SLB-WideFrac (YF)':
    df2['Stimulation Fluid'][i] = 10
  elif df2['Stimulation Fluid'][i] == 'Water: CSG-Optimum':
    df2['Stimulation Fluid'][i] = 11
  elif df2['Stimulation Fluid'][i] == 'Water: SLB-WideFrac (YF)/HiWAY':
    df2['Stimulation Fluid'][i] = 12
  elif df2['Stimulation Fluid'][i] == 'Slickwater':
    df2['Stimulation Fluid'][i] = 13
  elif df2['Stimulation Fluid'][i] == 'Slickwater: STEP-SW':
    df2['Stimulation Fluid'][i] = 14
  elif df2['Stimulation Fluid'][i] == 'Slickwater: BJ-ThinFrac':
    df2['Stimulation Fluid'][i] = 15
  elif df2['Stimulation Fluid'][i] == 'Slickwater: CWS-600':
    df2['Stimulation Fluid'][i] = 16
  elif df2['Stimulation Fluid'][i] == 'Slickwater: TWS-EcoClean-GSW':
    df2['Stimulation Fluid'][i] = 17
  elif df2['Stimulation Fluid'][i] == 'Slickwater: CSG-Optimum SW':
    df2['Stimulation Fluid'][i] = 18
  elif df2['Stimulation Fluid'][i] == 'Slickwater & Water':
    df2['Stimulation Fluid'][i] = 19
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# ...

# %% [markdown]
# Proppant Composition Preprocessing

# %%
for i in range(8352):
  if df2['Proppant Composition'][i] == 'Ceramic/Sand':
    df2['Proppant Composition'][i] = 0
  elif df2['Proppant Composition'][i] == 'Sand':
    df2['Proppant Composition'][i] = 1
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# Proppant Name 1 Preprocessing

# %%
for i in range(8352):
  if df2['Proppant Name 1'][i] == 'FTecISP':
    df2['Proppant Name 1'][i] = 0
  elif df2['Proppant Name 1'][i] == 'HydroProp':
    df2['Proppant Name 1'][i] = 1
  elif df2['Proppant Name 1'][i] == 'Sand':
    df2['Proppant Name 1'][i] = 2
  elif df2['Proppant Name 1'][i] == 'White':
    df2['Proppant Name 1'][i] = 3
  elif df2['Proppant Name 1'][i] == 'Imported':
    df2['Proppant Name 1'][i] = 4
  elif df2['Proppant Name 1'][i] == 'Badger':
    df2['Proppant Name 1'][i] = 5
  elif df2['Proppant Name 1'][i] == 'Domestic':
    df2['Proppant Name 1'][i] = 6
  elif df2['Proppant Name 1'][i] == 'Brown':
    df2['Proppant Name 1'][i] = 7
  elif df2['Proppant Name 1'][i] == 'EconoProp':
    df2['Proppant Name 1'][i] = 8
  elif df2['Proppant Name 1'][i] == 'Ceramic':
    df2['Proppant Name 1'][i] = 9
  elif df2['Proppant Name 1'][i] == 'FTec':
    df2['Proppant Name 1'][i] = 10
  elif df2['Proppant Name 1'][i] == 'Oxane Ceramic':
    df2['Proppant Name 1'][i] = 11
  elif df2['Proppant Name 1'][i] == 'Ottawa':
    df2['Proppant Name 1'][i] = 12
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %% [markdown]
# Proppant Size 1 Preprocessing

# %%
for i in range(8352):
  for j in str(df2['Proppant Size 1'][i]):
    if j == '/':
      a1 = str(df2['Proppant Size 1'][i])[0:2]
      a2 = str(df2['Proppant Size 1'][i])[3:5]
      a1 = int(a1)
      a2 = int(a2)
      df2['Proppant Size 1'][i] = (a1 + a2) / 2
    else:
      continue
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# # **EDA**

# %%
df1.plot.scatter(x='Reference (KB) Elev. (ft)',y='Y_first6',s=10, alpha=1)

# %%
df1.plot.scatter(x='MD (All Wells) (ft)',y='Y_first6',s=10, alpha=1)

# %%
df1.plot.scatter(x='TVD (ft)',y='Y_first6',s=10, alpha=1)

# %%
test1 = []
test2 = []
for i in range(280):
  if df1['Bot-Hole direction (N/S)/(E/W)'][i] < 2:
    test1.append(df1['Bot-Hole direction (N/S)/(E/W)'][i])
    test2.append(df1['Y_first6'][i])

plt.scatter(x = test1,y = test2,s=10, alpha=1)
df1.plot.scatter(x = 'Bot-Hole direction (N/S)/(E/W)', y = 'Y_first6', s = 10, alpha = 0.1)

# %%
df1.plot.scatter(x='Bot-Hole Easting (NAD83)',y='Y_first6',s=10, alpha=1)
df1.plot.scatter(x='Bot-Hole Northing (NAD83)',y='Y_first6',s=10, alpha=1)

# %%
df1.plot.scatter(x='Stimulation Fluid',y='Y_first6',s=10, alpha=0.3)
df1.plot.scatter(x='Stimulation Fluid',y='Y_first6',s=10, alpha=0.3)
df1.plot.scatter(x='Stimulation Fluid',y='Y_first6',s=10, alpha=0.3)

# %%
df1.plot.scatter(x = 'Stages Actual', y = 'Y_first6', s = 10, alpha =1 )
df1.plot.scatter(x = 'Total Proppant Placed (tonne)', y = 'Y_first6', s = 10, alpha = 1)
df1.plot.scatter(x = 'Avg Proppant Placed per Stage (tonne)', y = 'Y_first6', s = 10, alpha = 1)

# %%
df1.plot.scatter(x = 'Stages Actual', y = 'Y_first6', s = 10, alpha =1 )
df1.plot.scatter(x = 'Avg Fluid Pumped per Stage (m3)', y = 'Y_first6', s = 10, alpha = 1)
df1.plot.scatter(x = 'Total Fluid Pumped (m3)', y = 'Y_first6', s = 10, alpha = 1)

# %% [markdown]
# # **ExamSet Preprocessing**

# %%
examset = pd.read_csv('/gdrive/My Drive/DS_contest/examSet.csv')

# %%
examtsa = []
for i in range(len(examset)):
  examtsa.append(examset.iloc[i])

# %%
arb = []
arbdf = []
for i in range(44):
  arb.append(examtsa[i])
  examtsa[i] = examtsa[i].to_frame().transpose()
  arbdf.append(examtsa[i])

# %%
for i in range(44):
  for j in range(28):
    examtsa[i] = pd.concat([examtsa[i],arbdf[i]],axis=0,sort=False, join='outer')

# %%
# 31~60 GAS, 61~90 CND, 91~120 HRS
for i in range(44):
  GAS_list = []
  CND_list = []
  HRS_list = []
  for j in range(29):
    GAS_list.append(arb[i][j+31])
    CND_list.append(arb[i][j+61])
    HRS_list.append(arb[i][j+91])
  examtsa[i]['Y_t'] = GAS_list
  examtsa[i]['C_t'] = CND_list
  examtsa[i]['J_t'] = HRS_list

# %%
for i in range(44):
  for j in range(29):
    examtsa[i] = examtsa[i].drop('GAS_MONTH_'+str(j+1),axis=1)
    examtsa[i] = examtsa[i].drop('CND_MONTH_'+str(j+1),axis=1)
    examtsa[i] = examtsa[i].drop('HRS_MONTH_'+str(j+1),axis=1)

# %%
for i in range(44):
  time_list = []
  # time_list의 첫항은 Last month - on month + 1
  time_list.append((dt.datetime.strptime(arb[i]['Last Prod. YYYY/MM'],'%Y.%m.%d') - dt.datetime.strptime(arb[i]['On Prod YYYY/MM/DD'],'%Y.%m.%d') - dt.timedelta(days=1095)).days // 30 + 1)
  for j in range(28):
    time_list.append(time_list[j]+1)
  examtsa[i]['time'] = time_list

# %%
for i in range(44):
  for j in list(examtsa[i].columns.values):
    if j != 'No' and j != 'CPA Pretty Well ID' and j!= 'time' and j!= 'Y_t' and j!='J_t' and j!='PRICE ($)' and j!='Per Month Operation Cost ($)':
      examtsa[i] = examtsa[i].drop(j,axis=1)

# %%
examTSA = examtsa[0]
for i in range(43):
  examTSA = pd.concat([examTSA,examtsa[i+1]],axis=0,sort=False, join='outer')

# %%
data_ = []
for i in range(44):
  data_.append(examTSA[examTSA['No']==i])
data_x = []
for i in range(44):
  data_x.append(examTSA[(examTSA['No']==i) & (examTSA['J_t']>400)])
examTSA['normal'] = (examTSA['J_t']>400)
examTSA = examTSA.astype({'normal':'int'})
examTSA
# Out:
#      No CPA Pretty Well ID PRICE ($)  ...    J_t  time  normal
# 0    37                 17   1129000  ...    NaN   -15       0
# 0    37                 17   1129000  ...    NaN   -14       0
# 0    37                 17   1129000  ...    NaN   -13       0
# 0    37                 17   1129000  ...    NaN   -12       0
# 0    37                 17   1129000  ...    NaN   -11       0
# ..  ...                ...       ...  ...    ...   ...     ...
# 43  863                343    591000  ...  311.0    83       0
# 43  863                343    591000  ...  614.0    84       1
# 43  863                343    591000  ...  200.0    85       0
# 43  863                343    591000  ...  259.0    86       0
# 43  863                343    591000  ...  371.0    87       0
#
# [1276 rows x 8 columns]

# %%
for i in range(0, 15):
  examTSA['time'][i] = 0
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
examTSA
# Out:
#      No CPA Pretty Well ID PRICE ($)  ...    J_t  time  normal
# 0    37                 17   1129000  ...    NaN     0       0
# 0    37                 17   1129000  ...    NaN     0       0
# 0    37                 17   1129000  ...    NaN     0       0
# 0    37                 17   1129000  ...    NaN     0       0
# 0    37                 17   1129000  ...    NaN     0       0
# ..  ...                ...       ...  ...    ...   ...     ...
# 43  863                343    591000  ...  311.0    83       0
# 43  863                343    591000  ...  614.0    84       1
# 43  863                343    591000  ...  200.0    85       0
# 43  863                343    591000  ...  259.0    86       0
# 43  863                343    591000  ...  371.0    87       0
#
# [1276 rows x 8 columns]

# %% [markdown]
# # **ExamSet Preprocessing**

# %%
df1 = pd.read_csv('/gdrive/My Drive/DS_contest/examSet.csv')

# %%
for i in range(15, 44):
  df1 = df1.drop(i,axis=0)

# %%
for i in range(len(df1)):
  if df1['Stimulation Fluid'][i] == 'Oil':
    df1['Stimulation Fluid'][i] = 0
  elif df1['Stimulation Fluid'][i] == 'Oil: CWS-DynaGel':
    df1['Stimulation Fluid'][i] = 1
  elif df1['Stimulation Fluid'][i] == 'Oil: HAL-My-T-Oil':
    df1['Stimulation Fluid'][i] = 2
  elif df1['Stimulation Fluid'][i] == 'Oil: BJ-Super Rheo Gel':
    df1['Stimulation Fluid'][i] = 3
  elif df1['Stimulation Fluid'][i] == 'Water':
    df1['Stimulation Fluid'][i] = 4
  elif df1['Stimulation Fluid'][i] == 'Water: SLB-WaterFrac (WF)':
    df1['Stimulation Fluid'][i] = 5
  elif df1['Stimulation Fluid'][i] == 'Water: HAL-Hybor':
    df1['Stimulation Fluid'][i] = 6
  elif df1['Stimulation Fluid'][i] == 'Water: HAL-Water Frac G':
    df1['Stimulation Fluid'][i] = 7
  elif df1['Stimulation Fluid'][i] == 'Water: Sanjel-N2 FOAMjel':
    df1['Stimulation Fluid'][i] = 8
  elif df1['Stimulation Fluid'][i] == 'Water: TWS-Nitrified Foam (NF)':
    df1['Stimulation Fluid'][i] = 9
  elif df1['Stimulation Fluid'][i] == 'Water: SLB-WideFrac (YF)':
    df1['Stimulation Fluid'][i] = 10
  elif df1['Stimulation Fluid'][i] == 'Water: CSG-Optimum':
    df1['Stimulation Fluid'][i] = 11
  elif df1['Stimulation Fluid'][i] == 'Water: SLB-WideFrac (YF)/HiWAY':
    df1['Stimulation Fluid'][i] = 12
  elif df1['Stimulation Fluid'][i] == 'Slickwater':
    df1['Stimulation Fluid'][i] = 13
  elif df1['Stimulation Fluid'][i] == 'Slickwater: STEP-SW':
    df1['Stimulation Fluid'][i] = 14
  elif df1['Stimulation Fluid'][i] == 'STEP-SW':
    df1['Stimulation Fluid'][i] = 14
  elif df1['Stimulation Fluid'][i] == 'Slickwater: BJ-ThinFrac':
    df1['Stimulation Fluid'][i] = 15
  elif df1['Stimulation Fluid'][i] == 'Slickwater: CWS-600':
    df1['Stimulation Fluid'][i] = 16
  elif df1['Stimulation Fluid'][i] == 'Slickwater: TWS-EcoClean-GSW':
    df1['Stimulation Fluid'][i] = 17
  elif df1['Stimulation Fluid'][i] == 'Slickwater: CSG-Optimum SW':
    df1['Stimulation Fluid'][i] = 18
  elif df1['Stimulation Fluid'][i] == 'Slickwater & Water':
    df1['Stimulation Fluid'][i] = 19
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:29: SettingWithCopyWarning:
# ...

# %%
for i in range(len(df1)):
  if df1['Proppant Composition'][i] == 'Ceramic/Sand':
    df1['Proppant Composition'][i] = 0
  elif df1['Proppant Composition'][i] == 'Sand':
    df1['Proppant Composition'][i] = 1
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
for i in range(len(df1)):
  if df1['Proppant Name 1'][i] == 'FTecISP':
    df1['Proppant Name 1'][i] = 0
  elif df1['Proppant Name 1'][i] == 'HydroProp':
    df1['Proppant Name 1'][i] = 1
  elif df1['Proppant Name 1'][i] == 'Sand':
    df1['Proppant Name 1'][i] = 2
  elif df1['Proppant Name 1'][i] == 'White':
    df1['Proppant Name 1'][i] = 3
  elif df1['Proppant Name 1'][i] == 'Imported':
    df1['Proppant Name 1'][i] = 4
  elif df1['Proppant Name 1'][i] == 'Badger':
    df1['Proppant Name 1'][i] = 5
  elif df1['Proppant Name 1'][i] == 'Domestic':
    df1['Proppant Name 1'][i] = 6
  elif df1['Proppant Name 1'][i] == 'Brown':
    df1['Proppant Name 1'][i] = 7
  elif df1['Proppant Name 1'][i] == 'EconoProp':
    df1['Proppant Name 1'][i] = 8
  elif df1['Proppant Name 1'][i] == 'Ceramic':
    df1['Proppant Name 1'][i] = 9
  elif df1['Proppant Name 1'][i] == 'FTec':
    df1['Proppant Name 1'][i] = 10
  elif df1['Proppant Name 1'][i] == 'Oxane Ceramic':
    df1['Proppant Name 1'][i] = 11
  elif df1['Proppant Name 1'][i] == 'Ottawa':
    df1['Proppant Name 1'][i] = 12
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
for i in range(len(df1)):
  for j in str(df1['Proppant Size 1'][i]):
    if j == '/':
      a1 = str(df1['Proppant Size 1'][i])[0:2]
      a2 = str(df1['Proppant Size 1'][i])[3:5]
      a1 = int(a1)
      a2 = int(a2)
      df1['Proppant Size 1'][i] = (a1 + a2) / 2
    else:
      continue
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df1['SF_oil'] = (df1['Stimulation Fluid']<=3)
df1['SF_water'] = ((df1['Stimulation Fluid']>3) & (df1['Stimulation Fluid']<=12)) | (df1['Stimulation Fluid']==19)
df1['SF_slickwater'] = (df1['Stimulation Fluid']>12)
df1['PC_ceramic'] = (df1['Proppant Composition']==0)
df1['PC_sand'] = (df1['Proppant Composition']==1)

# %%
df1 = df1.astype({'SF_oil':'int', 'SF_water':'int', 'SF_slickwater':'int', 'PC_ceramic':'int', 'PC_sand':'int'})

# %%
df1 = df1.drop(columns=['Stimulation Fluid','Proppant Composition', 'Proppant Name 1', 'Reference (KB) Elev. (ft)', 'Ground Elevation (ft)'],axis=1)

# %%
df1 = df1.drop('On Prod YYYY/MM/DD', axis = 1)
df1 = df1.drop('First Prod YYYY/MM', axis = 1)
df1 = df1.drop('Last Prod. YYYY/MM', axis = 1)

# %%
for j in range(30):
  df1 = df1.drop('GAS_MONTH_'+str(j+1),axis=1)
  df1 = df1.drop('CND_MONTH_'+str(j+1),axis=1)
  df1 = df1.drop('HRS_MONTH_'+str(j+1),axis=1)

# %%
df1 = df1.drop('PRICE ($)', axis = 1)
df1 = df1.drop('Per Month Operation Cost ($)', axis = 1)

# %%
df1_std = df1.drop(['No','SF_oil','SF_water','SF_slickwater','PC_ceramic','PC_sand'],axis=1)
df1_normal = df1.drop(['No','SF_oil','SF_water','SF_slickwater','PC_ceramic','PC_sand'],axis=1)
# Out:
#     CPA Pretty Well ID  ...  Total Sand Proppant Placed (tonne)
# 0                 17.0  ...                             4278.80
# 1                 18.0  ...                             4707.00
# 2                 19.0  ...                             3803.10
# 3                 20.0  ...                             4461.10
# 4                 23.0  ...                             5330.00
# 5                 24.0  ...                             5167.00
# 6                 25.0  ...                             6568.00
# 7                 26.0  ...                             7801.00
# 8                 39.0  ...                             3780.00
# 9                 98.0  ...                             5622.00
# 10                99.0  ...                             3442.00
# 11               100.0  ...                             5511.56
# 12               126.0  ...                              590.10
# 13               132.0  ...                              559.79
# ...

# %%
def feature_scaling(df, scaling_strategy="z-score", column=None):
    if column == None:
        column = [column_name for column_name in df.columns]
    for column_name in column:
        if scaling_strategy == "min-max":
            df[column_name] = ( df[column_name] - df[column_name].min() ) /\
                            (df[column_name].max() - df[column_name].min()) 
        elif scaling_strategy == "z-score":
            df[column_name] = ( df[column_name] - \
                               df[column_name].mean() ) /\
                            (df[column_name].std() )
    return df

# %% [markdown]
# # **Correlation**

# %%
Data1 = pd.read_csv('/gdrive/My Drive/DS_contest/data1.csv')

# %%
corr = Data1.corr(method = 'pearson')
for i in corr:
  if i != 'Y_first6':
    corr = corr.drop(i,axis=1)
corr = corr.drop('Unnamed: 0',axis=0)
corr = corr.drop('Unnamed: 0.1',axis=0)
corr = corr.drop('Unnamed: 0.1.1',axis=0)
corr = corr.drop('No',axis=0)
corr = corr.drop('Y_first6', axis = 0)
print(corr)
# Out:
#                                        Y_first6
# Reference (KB) Elev. (ft)              0.250145
# Ground Elevation (ft)                  0.252996
# MD (All Wells) (ft)                    0.196756
# TVD (ft)                               0.351516
# Bot-Hole direction (N/S)/(E/W)        -0.013782
# Bot-Hole Easting (NAD83)              -0.111519
# Bot-Hole Northing (NAD83)             -0.382360
# Stimulation Fluid                      0.131790
# Total Proppant Placed (tonne)          0.342124
# Avg Proppant Placed per Stage (tonne)  0.303808
# Total Fluid Pumped (m3)                0.170739
# Avg Fluid Pumped per Stage (m3)        0.175095
# Stages Actual                          0.032256
# Completed Length (m)                   0.161921
# Avg Frac Spacing (m)                   0.005335
# Load Fluid Rec (m3)                    0.125139
# Load Fluid (m3)                        0.142068
# Avg Fluid Pumped / Meter (m3)          0.112374
# Avg Proppant Placed / Meter (tonne)    0.233632
# ...

# %%
corr_index = list(corr.index)
for i in range(len(corr['Y_first6'])):
  if corr_index[i] != 'Stimulation Fluid' and corr_index[i] != 'Proppant Composition' and corr_index[i] != 'Proppant Name 1':
    if corr['Y_first6'][corr_index[i]] <= 0.3:
      Data1 = Data1.drop(corr_index[i],axis=1)
      corr = corr.drop(corr_index[i], axis=0)
    else:
      continue

# %%
print(Data1)
# Out:
#      Unnamed: 0  Unnamed: 0.1  ...  Total Sand Proppant Placed (tonne)      Y_first6
# 0             0             0  ...                              558.91   99580.58333
# 1             1             1  ...                             3715.35   82942.66667
# 2             2             2  ...                             5131.40   55833.66667
# 3             3             3  ...                             3044.00   95592.08333
# 4             4             4  ...                             5374.00  104730.33330
# ..          ...           ...  ...                                 ...           ...
# 275         275           275  ...                             6209.34   43417.00000
# 276         276           276  ...                             4802.42   46754.00000
# 277         277           277  ...                             4395.30   20921.00000
# 278         278           278  ...                             4422.90   56508.16667
# ...

# %%
print(corr)
# Out:
#                                        Y_first6
# TVD (ft)                               0.351516
# Stimulation Fluid                      0.131790
# Total Proppant Placed (tonne)          0.342124
# Avg Proppant Placed per Stage (tonne)  0.303808
# Proppant Composition                   0.141696
# Proppant Name 1                       -0.182734
# Total Sand Proppant Placed (tonne)     0.327256

# %%
Data1 = Data1.drop('Unnamed: 0',axis=1)

# %%
Data1.plot.scatter(x='Stimulation Fluid',y='Y_first6',s=10, alpha=0.3)
Data1.plot.scatter(x='Proppant Composition',y='Y_first6',s=10, alpha=0.3)
Data1.plot.scatter(x='Proppant Name 1',y='Y_first6',s=10, alpha=0.3)

# %%
Mid = pd.read_csv('/gdrive/My Drive/DS_contest/data1_mid.csv')

# %%
for i in range(len(Mid)):
  for j in range(0, 4):
    if j == Mid['Stimulation Fluid'][i]:
      Mid['Stimulation Fluid'][i] = 0
  for j in range(4, 13):
    if j == Mid['Stimulation Fluid'][i]:
      Mid['Stimulation Fluid'][i] = 1
  for j in range(13, 20):
    if j == Mid['Stimulation Fluid'][i]:
      Mid['Stimulation Fluid'][i] = 2
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
Mid.plot.scatter(x='Stimulation Fluid',y='Y_first6',s=10, alpha=0.3)

# %%
list0 = []
list1 = []
list2 = []
avg0 = 0
avg1 = 0
avg2 = 0
for i in range(len(Mid)):
  if Mid['Stimulation Fluid'][i] == 0:
    list0.append(Mid['Y_first6'][i])
  elif Mid['Stimulation Fluid'][i] == 1:
    list1.append(Mid['Y_first6'][i])
  elif Mid['Stimulation Fluid'][i] == 2:
    list2.append(Mid['Y_first6'][i])

avg0 = sum(list0) / len(list0)
avg1 = sum(list1) / len(list1)
avg2 = sum(list2) / len(list2)
avg_list = []

for i in range(len(Mid)):
  if Mid['Stimulation Fluid'][i] == 0:
    avg_list.append(avg0)
  elif Mid['Stimulation Fluid'][i] == 1:
    avg_list.append(avg1)
  elif Mid['Stimulation Fluid'][i] == 2:
    avg_list.append(avg2)
x = Mid['Stimulation Fluid']
y = avg_list
plt.scatter(x, y)
print(len(list0))
print(len(list1))
print(len(list2))
# Out:
# 24
# 229
# 27

# %%
list0 = []
list1 = []
list2 = []
list3 = []
list4 = []
list5 = []
list6 = []
list7 = []
list8 = []
list9 = []
list10 = []
list11 = []
list12 = []
avg0 = 0
avg1 = 0
avg2 = 0
avg3 = 0
avg4 = 0
avg5 = 0
avg6 = 0
avg7 = 0
avg8 = 0
avg9 = 0
avg10 = 0
avg11 = 0
avg12 = 0

for i in range(len(Mid)):
  if Mid['Proppant Name 1'][i] == 0:
    list0.append(Mid['Y_first6'][i])
  elif Mid['Proppant Name 1'][i] == 1:
    list1.append(Mid['Y_first6'][i])
  elif Mid['Proppant Name 1'][i] == 2:
    list2.append(Mid['Y_first6'][i])
  elif Mid['Proppant Name 1'][i] == 3:
    list3.append(Mid['Y_first6'][i])
  elif Mid['Proppant Name 1'][i] == 4:
    list4.append(Mid['Y_first6'][i])
  elif Mid['Proppant Name 1'][i] == 5:
    list5.append(Mid['Y_first6'][i])
  elif Mid['Proppant Name 1'][i] == 6:
    list6.append(Mid['Y_first6'][i])
  elif Mid['Proppant Name 1'][i] == 7:
    list7.append(Mid['Y_first6'][i])
  elif Mid['Proppant Name 1'][i] == 8:
    list8.append(Mid['Y_first6'][i])
  elif Mid['Proppant Name 1'][i] == 9:
    list9.append(Mid['Y_first6'][i])
  elif Mid['Proppant Name 1'][i] == 10:
    list10.append(Mid['Y_first6'][i])
  elif Mid['Proppant Name 1'][i] == 11:
    list11.append(Mid['Y_first6'][i])
  elif Mid['Proppant Name 1'][i] == 12:
    list12.append(Mid['Y_first6'][i])

avg0 = sum(list0) / len(list0)
avg1 = sum(list1) / len(list1)
avg2 = sum(list2) / len(list2)
avg3 = sum(list3) / len(list3)
avg4 = sum(list4) / len(list4)
avg5 = sum(list5) / len(list5)
avg6 = sum(list6) / len(list6)
avg7 = sum(list7) / len(list7)
avg8 = sum(list8) / len(list8)
avg9 = sum(list9) / len(list9)
avg10 = sum(list10) / len(list10)
avg11 = sum(list11) / len(list11)
avg12 = sum(list12) / len(list12)
avg_list = []

for i in range(len(Mid)):
  if Mid['Proppant Name 1'][i] == 0:
    avg_list.append(avg0)
  elif Mid['Proppant Name 1'][i] == 1:
    avg_list.append(avg1)
  elif Mid['Proppant Name 1'][i] == 2:
    avg_list.append(avg2)
  elif Mid['Proppant Name 1'][i] == 3:
    avg_list.append(avg3)
  elif Mid['Proppant Name 1'][i] == 4:
    avg_list.append(avg4)
  elif Mid['Proppant Name 1'][i] == 5:
    avg_list.append(avg5)
  elif Mid['Proppant Name 1'][i] == 6:
    avg_list.append(avg6)
  elif Mid['Proppant Name 1'][i] == 7:
    avg_list.append(avg7)
  elif Mid['Proppant Name 1'][i] == 8:
    avg_list.append(avg8)
  elif Mid['Proppant Name 1'][i] == 9:
    avg_list.append(avg9)
  elif Mid['Proppant Name 1'][i] == 10:
    avg_list.append(avg10)
  elif Mid['Proppant Name 1'][i] == 11:
    avg_list.append(avg11)
  elif Mid['Proppant Name 1'][i] == 12:
    avg_list.append(avg12)
x = Mid['Proppant Name 1']
y = avg_list
plt.scatter(x, y)
print((len(list0), len(list1), len(list2), len(list3), len(list4), len(list5), len(list6), len(list7), len(list8), len(list9), len(list10), len(list11), len(list12)))
# Out:
# (1, 27, 171, 17, 19, 2, 9, 2, 19, 5, 1, 4, 3)

# %%
corr = Mid.corr(method = 'pearson')
for i in Mid:
  if i == 'Unnamed: 0':
    continue
  else:
    print(i)
    print(' ')
    print(corr[i])
    print(' ')
# Out:
# No
#
# Unnamed: 0                               0.401740
# No                                       1.000000
# TVD (ft)                                -0.130644
# Stimulation Fluid                        0.238309
# Total Proppant Placed (tonne)            0.173506
# Avg Proppant Placed per Stage (tonne)   -0.107486
# Proppant Composition                     0.348086
# Proppant Name 1                         -0.030366
# Total Sand Proppant Placed (tonne)       0.195749
# Y_first6                                -0.220723
# Name: No, dtype: float64
#
# TVD (ft)
#
# Unnamed: 0                              -0.182009
# No                                      -0.130644
# TVD (ft)                                 1.000000
# Stimulation Fluid                       -0.028723
# Total Proppant Placed (tonne)           -0.024912
# Avg Proppant Placed per Stage (tonne)   -0.014149
# Proppant Composition                    -0.091773
# Proppant Name 1                          0.200411
# ...

# %%
Mid = Mid.drop('Avg Proppant Placed per Stage (tonne)',axis=1)
Mid = Mid.drop('Proppant Composition',axis=1)
Mid = Mid.drop('Unnamed: 0', axis = 1)

# %%
corr = Mid.corr(method = 'pearson')
for i in Mid:
  if i == 'Unnamed: 0':
    continue
  else:
    print(i)
    print(' ')
    print(corr[i])
    print(' ')
# Out:
# No
#
# No                                    1.000000
# TVD (ft)                             -0.130644
# Stimulation Fluid                     0.238309
# Total Proppant Placed (tonne)         0.173506
# Proppant Name 1                      -0.030366
# Total Sand Proppant Placed (tonne)    0.195749
# Y_first6                             -0.220723
# Name: No, dtype: float64
#
# TVD (ft)
#
# No                                   -0.130644
# TVD (ft)                              1.000000
# Stimulation Fluid                    -0.028723
# Total Proppant Placed (tonne)        -0.024912
# Proppant Name 1                       0.200411
# Total Sand Proppant Placed (tonne)   -0.033974
# Y_first6                              0.351516
# Name: TVD (ft), dtype: float64
#
# Stimulation Fluid
#
# No                                    0.238309
# TVD (ft)                             -0.028723
# Stimulation Fluid                     1.000000
# Total Proppant Placed (tonne)         0.475028
# ...

# %%
Mid = Mid.drop('',axis=1)
# Out:
#       No  TVD (ft)  ...  Total Sand Proppant Placed (tonne)      Y_first6
# 0    354     10746  ...                              558.91   99580.58333
# 1    372     10440  ...                             3715.35   82942.66667
# 2    383     10745  ...                             5131.40   55833.66667
# 3    395     10884  ...                             3044.00   95592.08333
# 4    397     10916  ...                             5374.00  104730.33330
# ..   ...       ...  ...                                 ...           ...
# 275  708     10351  ...                             6209.34   43417.00000
# 276  716     10036  ...                             4802.42   46754.00000
# 277  718     10112  ...                             4395.30   20921.00000
# 278  720     10218  ...                             4422.90   56508.16667
# 279  722     10130  ...                             4479.20   36691.33333
#
# [280 rows x 7 columns]

# %% [markdown]
# # **Save**

# %%
df1.to_csv('/gdrive/My Drive/DS_contest/df1.csv')
