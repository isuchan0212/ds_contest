# %%
from google.colab import drive
drive.mount('/gdrive', force_remount=True)
# Out:
# Mounted at /gdrive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
from sklearn.linear_model import LinearRegression

# %%
data1=pd.read_csv('/gdrive/My Drive/DS_contest/datathree_Interpolation_2.csv')

# %%
real_list=[]
pred_list=[]
for num in range(232):
  train_x = data1['time'][num*12:num*12+10]
  train_Y = data1['Interpolated X_t'][num*12:num*12+10]
  train_y = []
  for i in train_Y:
    train_y.append(math.log(i))
  train_y = np.array(train_y)
  jf_data=data1['J_t_pred'][num]
  ja_data=data1["J_t"][num]

  lgr = LinearRegression()
  lgr.fit(train_x.values.reshape(-1, 1), train_y)

  X11 = data1['Interpolated X_t'][num*12+10]
  X12 = data1['Interpolated X_t'][num*12+11]
  real_list.append((X11 + X12)**ja_data)
  t11 = data1['time'][num*12 + 10]
  t12 = data1['time'][num*12 + 11]
  pred_list.append((math.exp(lgr.predict(t11)) + math.exp(lgr.predict(t12)))*jf_data)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:19: RuntimeWarning: overflow encountered in double_scalars
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-cd0e2eecc1c5> in <module>()
#      20   t11 = data1['time'][num*12 + 10]
#      21   t12 = data1['time'][num*12 + 11]
# ---> 22   pred_list.append(((math.exp(lgr.predict(t11)).values.reshape(-1, 1) + math.exp(lgr.predict(t12))).values.reshape(-1, 1)*jf_data))
#
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_base.py in predict(self, X)
#     360             Returns predicted values.
#     361         """
# --> 362         return self._decision_function(X)
#     363
#     364     _preprocess_data = staticmethod(_preprocess_data)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_base.py in _decision_function(self, X)
#     343         check_is_fitted(self)
# ...

# %%
def smape(A, F):
  return 100/len(A) * np.sum(np.abs(F-A) / (np.abs(A) + np.abs(F)))

# %%
Aarr=np.array(Actual)
Farr=np.array(Forecast)

# %%
print(smape(Aarr, Farr))
