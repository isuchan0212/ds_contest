# %%
from google.colab import drive
drive.mount('/gdrive', force_remount=True)
# Out:
# Mounted at /gdrive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as plot
import datetime as dt
import math

# %%
df = pd.read_csv('/gdrive/My Drive/DS_contest/examdata1.csv')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'No', 'CPA Pretty Well ID', 'MD (All Wells) (ft)',
#        'TVD (ft)', 'Bot-Hole direction (N/S)/(E/W)',
#        'Bot-Hole Easting (NAD83)', 'Bot-Hole Northing (NAD83)',
#        'Total Proppant Placed (tonne)',
#        'Avg Proppant Placed per Stage (tonne)', 'Total Fluid Pumped (m3)',
#        'Avg Fluid Pumped per Stage (m3)', 'Stages Actual',
#        'Completed Length (m)', 'Avg Frac Spacing (m)', 'Load Fluid Rec (m3)',
#        'Load Fluid (m3)', 'Avg Fluid Pumped / Meter (m3)',
#        'Avg Proppant Placed / Meter (tonne)', 'Proppant Size 1',
#        'Avg Proppant 1 Placed (tonne)', 'Total Proppant 1 Placed (tonne)',
#        'Total Ceramic Proppant Placed (tonne)',
#        'Total Sand Proppant Placed (tonne)', 'SF_oil', 'SF_water',
#        'SF_slickwater', 'PC_ceramic', 'PC_sand'],
#       dtype='object')

# %%
df = df.drop('Unnamed: 0', axis = 1)
df = df.drop('CPA Pretty Well ID', axis = 1)
df = df.drop('MD (All Wells) (ft)', axis = 1)
df = df.drop('Bot-Hole direction (N/S)/(E/W)', axis = 1)
df = df.drop('Bot-Hole Easting (NAD83)', axis = 1)
df = df.drop('Total Fluid Pumped (m3)', axis = 1)
df = df.drop('Completed Length (m)', axis = 1)
df = df.drop('Load Fluid Rec (m3)', axis = 1)
df = df.drop('Load Fluid (m3)', axis = 1)
df = df.drop('Avg Proppant Placed / Meter (tonne)', axis = 1)
df = df.drop('Avg Proppant 1 Placed (tonne)', axis = 1)
df = df.drop('Total Proppant 1 Placed (tonne)', axis = 1)
df = df.drop('Total Sand Proppant Placed (tonne)', axis = 1)
df = df.drop('SF_water', axis = 1)
df = df.drop('PC_ceramic', axis = 1)
df = df.drop('PC_sand', axis = 1)

# %%
df.head(5)
# Out:
#    No  TVD (ft)  ...  SF_oil  SF_slickwater
# 0  37     10367  ...       0              1
# 1  41     10516  ...       0              1
# 2  43     10355  ...       0              1
# 3  60     10136  ...       0              1
# 4  66     10164  ...       0              1
#
# [5 rows x 13 columns]

# %%
def feature_scaling(df, scaling_strategy="z-score", column=None):
    if column == None:
        column = [column_name for column_name in df.columns]
    for column_name in column:
        if scaling_strategy == "min-max":
            df[column_name] = ( df[column_name] - df[column_name].min() ) /\
                            (df[column_name].max() - df[column_name].min()) 
        elif scaling_strategy == "z-score":
            df[column_name] = ( df[column_name] - \
                               df[column_name].mean() ) /\
                            (df[column_name].std() )
    return df

# %%
df_std = df.drop(['No','SF_oil', 'SF_slickwater'],axis=1)

# %%
df_std = feature_scaling(df_std)
df_std.head(5)
# Out:
#    TVD (ft)  ...  Total Ceramic Proppant Placed (tonne)
# 0 -0.248971  ...                              -0.581376
# 1  0.231141  ...                              -0.581376
# 2 -0.287638  ...                              -0.581376
# 3 -0.993306  ...                              -0.581376
# 4 -0.903083  ...                              -0.581376
#
# [5 rows x 10 columns]

# %%
df_std['No'] = df['No']
df_std['SF_oil'] = df['SF_oil']
df_std['SF_slickwater'] = df['SF_slickwater']
df_normal['No'] = df['No']
df_normal['SF_oil'] = df['SF_oil']
df_normal['SF_slickwater'] = df['SF_slickwater']

# %%
df_std.to_csv('/gdrive/My Drive/DS_contest/examdata1.csv')
