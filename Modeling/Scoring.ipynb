# %%
import numpy as np
from sklearn.metrics import make_scorer

def sMAPE(actual_values, predicted_values, expsMAPE = False):
  '''
  logY를 regression하는 경우에 expsMAPE = True로 입력, 아니면 expsMAPE = False로 놔두면 됨
  reg_sMAPE = GridSearchCV(RandomForestRegressor(), {}, scoring=make_scorer(sMAPE, greater_is_better=False)) 이런식으로 쓰면됨
  reg_sMAPE.fit(x,y)
  '''
  if expsMAPE == True:
    predicted_values = np.exp(predicted_values)
    actual_values = np.exp(actual_values)
  return 1/len(actual_values) * np.sum(2*np.abs(actual_values - predicted_values) / (np.abs(actual_values) + np.abs(predicted_values)) * 100)
def expsMAPE(actual_values, predicted_values, expsMAPE = True):
  predicted_values = np.exp(predicted_values)
  actual_values = np.exp(actual_values)
  return 1/len(actual_values) * np.sum(2*np.abs(actual_values - predicted_values) / (np.abs(actual_values) + np.abs(predicted_values)) * 100)

# %%
def asdf(a,f):
  return 1/len(a) * np.sum(2 * np.abs(f-a) / (np.abs(a) + np.abs(f))*100)

# %%
pred_y = np.array([100,100,105,100,100])
real_y = np.array([100,100,95,100,100])
sMAPE(real_y, pred_y)
# Out:
# 2.0

# %%
sMAPE(real_y, pred_y, True)
# Out:
# 39.99636817050381

# %%
pred_y = [100,100,105,100,100]
real_y = [100,100,95,100,100]

# %%
sMAPE(real_y,pred_y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-e09561f2a9d0> in <module>()
# ----> 1 sMAPE(real_y,pred_y)
#
# <ipython-input-1-3b1f3579e134> in sMAPE(actual_values, predicted_values, expsMAPE)
#      11     predicted_values = np.exp(predicted_values)
#      12     actual_values = np.exp(actual_values)
# ---> 13   return 1/len(actual_values) * np.sum(2*np.abs(actual_values - predicted_values) / (np.abs(actual_values) + np.abs(predicted_values)) * 100)
#      14 def expsMAPE(actual_values, predicted_values, expsMAPE = True):
#      15   predicted_values = np.exp(predicted_values)
#
# TypeError: unsupported operand type(s) for -: 'list' and 'list'
